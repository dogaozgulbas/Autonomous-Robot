# %%
import cv2
import numpy as np
from PIL import Image,ImageOps
import matplotlib.pyplot as plt

# %%
image_row=Image.open('second_floor24.jpg')
image1 = np.array(image_row)
#plt.imshow(image1)
img = cv2.imread("second_floor24.jpg")
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
template = cv2.imread("second_floor23.jpg", cv2.IMREAD_GRAYSCALE)
w, h = template.shape[::-1]

result = cv2.matchTemplate(gray_img, template, cv2.TM_CCOEFF_NORMED)
loc = np.where(result >= 0.9)
print(loc)


for pt in zip(*loc[::-1]):
    cv2.rectangle(img, pt, (pt[0] + w, pt[1] + h), (0, 255, 0), 3)

#cv2.imshow("img", img)
#cv2.imshow("result",result)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
# Out:
# (array([96]), array([132]))

# %%
width=int(loc[0])
height=int(loc[1])
TTT=image1[240:350,:height]
plt.imshow(TTT)

#plt.imshow(image1[:,132:])
#cv2.imshow("result",result[width,height])
#cv2.waitKey(0)
#cv2.destroyAllWindows()
